# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

data = sns.load_dataset("tips")
# print(data.head())

sns.violinplot(data, x = "tip")
plt.show()

# %%
df = pd.read_excel("../Data/ESD.xlsx")
# print(data.head())

sns.violinplot(data = df, x = "Bonus %")
plt.show()
