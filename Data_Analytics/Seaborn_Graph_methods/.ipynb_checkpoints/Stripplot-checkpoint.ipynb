# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd


data = sns.load_dataset("tips")
# print(data)

sns.stripplot(data,x = "day", y = "total_bill" , hue= "sex", dodge=True, jitter = 0.5)
plt.show()
