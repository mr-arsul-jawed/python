# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

data = sns.load_dataset("tips")
# print(data)

sns.countplot(data, x = "day", hue="sex")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd


data = pd.read_excel("../Data/ESD.xlsx")
# print(data)



sns.countplot(data, x = "Department", hue="Gender")
plt.legend()
plt.show()
