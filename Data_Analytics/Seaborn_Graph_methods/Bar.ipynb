# %%
import seaborn as sns
import matplotlib.pyplot as plt

data = sns.load_dataset("tips")
# data = sns.load_dataset("iris")
# print(data)
sns.barplot(x="day", y="total_bill", data=data,hue="smoker",palette="muted")
plt.show()
