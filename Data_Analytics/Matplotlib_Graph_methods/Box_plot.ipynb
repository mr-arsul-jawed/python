# %%
import matplotlib.pyplot as plt


l = [25,46,57,25,78,89,45,23,45,67,89,90]

plt.boxplot(l)
plt.show()

# %%
import matplotlib.pyplot as plt


l = [1,3,4,7,12,2,8,9,24]
l1 = [2,3,4,5,3,5,7,3,6]

plt_values = [l, l1]
plt.boxplot(plt_values)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_excel("Data/expense.xlsx")
df  = pd.DataFrame(data)


plt.boxplot(df["Amount"])
plt.show()
